# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    randomNum = np.random.randint(1, window_size+1)
    start = idx - randomNum if (idx - randomNum) > 0 else 0 #negative numbers
    stop = idx + randomNum
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

x = get_target(train_words, 30)

for num in x:
    print(int_to_vocab[num])
# Out:
# chaos
# harmonious
# anarchy
# authoritarian
# anomie
# anarchists
# rather

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels = tf.placeholder(tf.int32, [None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    #embed > lookup table
    #n_vocab > number of classeds
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-28-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.7176 0.7373 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6174 0.5065 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5148 0.4982 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6178 0.4915 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5108 0.4909 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5175 0.4904 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5613 0.5106 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5446 0.5062 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4620 0.5063 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3836 0.4917 sec/batch
# Nearest to history: truscott, asparagine, unwavering, harmed, astute, worthiness, delaying, bully,
# Nearest to s: revue, matt, unification, kokhba, tenures, clotting, staind, distinctively,
# Nearest to system: dreadful, nai, ax, citigroup, corba, hypertrophy, kushan, lampooned,
# Nearest to his: capacity, denunciation, denominations, diane, estuaries, seabed, crusade, volts,
# Nearest to a: columnist, atlas, lunations, overstated, abnormality, barlow, captioned, kakinomoto,
# Nearest to an: krishnamurti, definiteness, archipelago, minimum, spare, shuffling, margrave, refinery,
# Nearest to these: baetica, afdb, overlapping, chroniclers, theorie, release, soybeans, three,
# Nearest to or: sf, summertime, conducted, crafted, solstices, aborigines, allende, bish,
# Nearest to grand: uninfected, breakdance, taming, integrator, jinx, gemini, award, lossless,
# Nearest to issue: retrieved, dared, esset, crouch, fgth, blackstone, marlin, fledging,
# Nearest to notes: bling, straining, apocalypses, antipope, testaments, cama, colossians, guilbert,
# Nearest to defense: uqqal, analogs, ukip, regarding, litoral, lamb, perception, midnight,
# Nearest to construction: angolan, cardoso, taxi, procedure, neopagan, replicant, displeased, rudd,
# Nearest to units: consult, surfacing, tent, gorge, nih, ammonius, ridinghood, men,
# Nearest to dr: juggalo, oshii, oilers, factorials, aneurin, asuka, tomahawk, revealing,
# Nearest to ice: optimality, brady, complicity, guan, vessels, prionailurus, muonium, robbery,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5006 0.5058 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3550 0.4895 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3409 0.4905 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2328 0.4905 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1619 0.4879 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1296 0.4934 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0806 0.4878 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0321 0.4900 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9997 0.5059 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9560 0.5127 sec/batch
# Nearest to history: ends, fingers, dresses, astute, delaying, harmed, truscott, asparagine,
# Nearest to s: revue, matt, unification, tenures, burden, kokhba, became, parents,
# Nearest to system: dreadful, focus, corba, ax, unknowns, extend, colloquium, absence,
# Nearest to his: capacity, denominations, denunciation, smaller, diane, volts, granted, seabed,
# Nearest to a: columnist, atlas, marko, cattle, dalriada, barlow, abnormality, latvia,
# Nearest to an: minimum, archipelago, definiteness, krishnamurti, spare, conversational, shuffling, bought,
# Nearest to these: overlapping, baetica, appropriate, facilitate, release, chroniclers, patterns, three,
# Nearest to or: sf, benefit, conducted, rugged, ratio, habitat, which, summertime,
# Nearest to grand: uninfected, breakdance, taming, award, integrator, jinx, synopsis, gemini,
# Nearest to issue: retrieved, crouch, dared, darker, rattled, marlin, esset, hugh,
# Nearest to notes: straining, bling, change, apocalypses, harry, leonard, testaments, map,
# Nearest to defense: perception, regarding, uqqal, analogs, lamb, mainly, midnight, litoral,
# Nearest to construction: procedure, angolan, cardoso, taxi, efficiency, since, evident, displeased,
# Nearest to units: consult, tent, surfacing, men, derision, gorge, concerned, nih,
# Nearest to dr: hence, give, revealing, introducing, pleasing, tomahawk, aneurin, juggalo,
# Nearest to ice: complicity, brady, guan, untouched, vessels, optimality, interacts, length,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9131 0.5052 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9256 0.4896 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8845 0.4864 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8523 0.4904 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7938 0.4892 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8264 0.4920 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8047 0.4855 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8007 0.4990 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7765 0.5197 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7984 0.4872 sec/batch
# Nearest to history: astute, harmed, truscott, dresses, delaying, ends, bully, worthiness,
# Nearest to s: revue, matt, burden, unification, tenures, parents, leap, kokhba,
# Nearest to system: dreadful, nai, unknowns, lampooned, adequately, ax, corba, phase,
# Nearest to his: capacity, denunciation, diane, watched, crusade, granted, denominations, hit,
# Nearest to a: columnist, marko, atlas, barlow, oversee, edible, abnormality, dalriada,
# Nearest to an: archipelago, krishnamurti, definiteness, spare, minimum, refinery, unprofitable, shuffling,
# Nearest to these: overlapping, chroniclers, baetica, facilitate, embodies, factorization, signifier, retreating,
# Nearest to or: rugged, sf, yourself, merkel, crafted, summertime, conducted, ratio,
# Nearest to grand: award, uninfected, taming, breakdance, integrator, goers, accusations, sneak,
# Nearest to issue: retrieved, dared, crouch, fgth, darker, agenda, coherent, constitutionality,
# Nearest to notes: change, straining, bling, leonard, harry, colossians, solidifying, apocalypses,
# Nearest to defense: regarding, perception, midnight, lamb, uqqal, mainly, bill, instances,
# Nearest to construction: angolan, cardoso, taxi, procedure, evident, jutes, demon, efficiency,
# Nearest to units: consult, tent, surfacing, men, derision, nih, gorge, concerned,
# Nearest to dr: pleasing, give, revealing, hence, budapest, oshii, introducing, oilers,
# Nearest to ice: complicity, brady, vessels, robbery, untouched, interacts, hollow, guan,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7861 0.4980 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7843 0.4881 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7125 0.4877 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7040 0.4844 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7408 0.4879 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6786 0.4901 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7042 0.4897 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7123 0.5109 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6781 0.5144 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6668 0.4860 sec/batch
# Nearest to history: harmed, astute, jordan, dresses, unwavering, bully, delaying, disengagement,
# Nearest to s: revue, matt, burden, tenures, unification, kokhba, parents, distinctively,
# Nearest to system: dreadful, unknowns, nai, lampooned, data, ax, willingly, adequately,
# Nearest to his: denunciation, capacity, crusade, watched, hit, flashes, clarkson, diane,
# Nearest to a: columnist, marko, atlas, overstated, diagnosed, oversee, lunations, dalriada,
# Nearest to an: definiteness, spare, archipelago, krishnamurti, refinery, floss, shuffling, minimum,
# Nearest to these: overlapping, chroniclers, theorie, signifier, facets, facilitate, baetica, factorization,
# Nearest to or: rugged, sf, summertime, yourself, merkel, legitimate, wintertime, crafted,
# Nearest to grand: taming, goers, uninfected, award, sneak, breakdance, integrator, accusations,
# Nearest to issue: retrieved, dared, crouch, fgth, blackstone, mcpherson, fledging, darker,
# Nearest to notes: bling, straining, solidifying, leonard, sharon, change, colossians, iala,
# Nearest to defense: regarding, lamb, purview, perception, uqqal, boyle, midnight, analogs,
# Nearest to construction: angolan, cardoso, jutes, taxi, procedure, courtyard, neopagan, associate,
# Nearest to units: consult, tent, surfacing, nih, gorge, men, anglophone, alden,
# Nearest to dr: pleasing, give, oilers, revealing, arno, oshii, hence, asuka,
# Nearest to ice: vessels, complicity, robbery, brady, hollow, prudent, untouched, guan,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6718 0.4874 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6875 0.4862 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6129 0.4916 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6307 0.4853 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6380 0.4858 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6161 0.4902 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6047 0.3544 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5730 0.4885 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4842 0.4902 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5176 0.4875 sec/batch
# Nearest to history: harmed, unwavering, dresses, astute, tribunes, jordan, bully, delaying,
# Nearest to s: revue, matt, distinctively, burden, tenures, unification, houston, kokhba,
# Nearest to system: dreadful, data, lampooned, phase, citigroup, unknowns, nai, adequately,
# Nearest to his: denunciation, crusade, capacity, watched, pullback, hit, flashes, clarkson,
# Nearest to a: columnist, lunations, diagnosed, marko, unsuspecting, atlas, modems, captioned,
# Nearest to an: definiteness, krishnamurti, spare, floss, refinery, shuffling, archipelago, minimum,
# Nearest to these: signifier, overlapping, theorie, chroniclers, facets, patterns, noche, appropriate,
# Nearest to or: rugged, yourself, universitas, legitimate, sf, which, summertime, coronal,
# Nearest to grand: goers, taming, uninfected, gemini, breakdance, porter, jinx, holliday,
# Nearest to issue: retrieved, dared, fledging, blackstone, fgth, crouch, mcpherson, esset,
# Nearest to notes: bling, straining, solidifying, testaments, iala, strenuously, antipope, sharon,
# Nearest to defense: purview, regarding, grandparents, daro, lamb, perception, uqqal, litoral,
# Nearest to construction: angolan, cardoso, courtyard, jutes, taxi, ngos, blocked, intramuscular,
# Nearest to units: consult, tent, surfacing, nih, damp, gorge, agr, deng,
# Nearest to dr: pleasing, oilers, arno, oshii, revealing, give, asuka, fernand,
# Nearest to ice: vessels, robbery, outgassing, optimality, brady, guan, prudent, untouched,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5079 0.4946 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5144 0.4891 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4678 0.4866 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5296 0.4868 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4841 0.4865 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4757 0.4998 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4556 0.5124 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3880 0.4964 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4199 0.4864 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4635 0.4846 sec/batch
# Nearest to history: harmed, jordan, unwavering, tribunes, astute, dresses, bully, disengagement,
# Nearest to s: revue, tenures, matt, distinctively, burden, lupin, cathari, houston,
# Nearest to system: dreadful, data, citigroup, unknowns, ax, mebyon, lampooned, netscape,
# Nearest to his: denunciation, crusade, watched, hit, pullback, clarkson, worshipped, famous,
# Nearest to a: columnist, lunations, unsuspecting, diagnosed, captioned, greenlandic, abnormality, connoisseurs,
# Nearest to an: definiteness, krishnamurti, spare, refinery, shuffling, minimum, floss, allocate,
# Nearest to these: overlapping, signifier, theorie, patterns, noche, appropriate, facets, subexpression,
# Nearest to or: rugged, which, universitas, legitimate, interconnected, coronal, bish, sf,
# Nearest to grand: taming, uninfected, goers, breakdance, porter, gemini, jinx, holliday,
# Nearest to issue: retrieved, fledging, blackstone, fgth, dared, mcpherson, crouch, esset,
# Nearest to notes: bling, solidifying, sharon, straining, iala, antipope, testaments, swim,
# Nearest to defense: purview, litoral, regarding, grandparents, perception, daro, boyle, euston,
# Nearest to construction: angolan, cardoso, courtyard, jutes, blocked, taxi, ngos, pontoon,
# Nearest to units: consult, tent, surfacing, numbering, zero, damp, deng, agr,
# Nearest to dr: pleasing, oilers, arno, oshii, revealing, asuka, maimon, give,
# Nearest to ice: vessels, outgassing, robbery, optimality, hollow, untouched, prudent, hetero,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4312 0.4924 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4370 0.4894 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4254 0.4854 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3967 0.4824 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4011 0.4843 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4377 0.4832 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4124 0.4870 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3753 0.4896 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4085 0.4859 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3934 0.4878 sec/batch
# Nearest to history: harmed, jordan, tribunes, unwavering, dresses, astute, bully, uis,
# Nearest to s: revue, tenures, matt, distinctively, lupin, cathari, hogmanay, burden,
# Nearest to system: dreadful, data, citigroup, mebyon, ax, adequately, corba, windows,
# Nearest to his: denunciation, crusade, famous, clarkson, nephew, friends, worshipped, watched,
# Nearest to a: lunations, unsuspecting, abnormality, quickest, columnist, diagnosed, oversee, greenlandic,
# Nearest to an: definiteness, krishnamurti, floss, allocate, shuffling, spare, straws, minimum,
# Nearest to these: signifier, appropriate, patterns, overlapping, noche, theorie, repetitive, subexpression,
# Nearest to or: legitimate, universitas, coronal, summertime, incapable, which, bish, bubi,
# Nearest to grand: goers, porter, taming, uninfected, breakdance, gemini, almoravid, holliday,
# Nearest to issue: retrieved, fledging, fgth, blackstone, dared, agenda, mcpherson, crouch,
# Nearest to notes: bling, solidifying, iala, pappus, sharon, testaments, swim, ancyra,
# Nearest to defense: purview, resign, grandparents, regarding, litoral, perception, instances, euston,
# Nearest to construction: angolan, cardoso, courtyard, pontoon, jutes, taxi, blocked, procedure,
# Nearest to units: consult, tent, deng, surfacing, numbering, zero, damp, agr,
# Nearest to dr: pleasing, oilers, arno, revealing, reuven, oshii, asuka, eleftherios,
# Nearest to ice: vessels, outgassing, hollow, untouched, robbery, optimality, muonium, prudent,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3723 0.4919 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4014 0.4840 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3581 0.4853 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3786 0.4879 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3845 0.5184 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3562 0.5084 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3893 0.4887 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3738 0.4870 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3198 0.4850 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3097 0.4882 sec/batch
# Nearest to history: jordan, harmed, unwavering, tribunes, astute, uis, bully, disengagement,
# Nearest to s: revue, tenures, matt, distinctively, lupin, cathari, burden, pumping,
# Nearest to system: data, dreadful, mib, citigroup, mebyon, corba, netscape, windows,
# Nearest to his: denunciation, crusade, worshipped, friends, nephew, famous, savior, died,
# Nearest to a: abnormality, lunations, unsuspecting, columnist, bedrooms, marko, validate, captioned,
# Nearest to an: definiteness, krishnamurti, floss, straws, shuffling, allocate, versatility, spare,
# Nearest to these: signifier, appropriate, overlapping, noche, subexpression, theorie, patterns, facets,
# Nearest to or: legitimate, wintertime, which, universitas, coronal, megali, summertime, bish,
# Nearest to grand: goers, porter, uninfected, holliday, taming, breakdance, gemini, paedophilia,
# Nearest to issue: retrieved, fgth, fledging, dared, blackstone, mcpherson, agenda, constitutionality,
# Nearest to notes: bling, solidifying, pappus, testaments, swim, ancyra, iala, critique,
# Nearest to defense: purview, grandparents, resign, regarding, litoral, euston, mandated, ukip,
# Nearest to construction: angolan, cardoso, pontoon, taxi, courtyard, jutes, blocked, goods,
# Nearest to units: consult, zero, tent, numbering, construction, surfacing, deng, agr,
# Nearest to dr: pleasing, oilers, arno, revealing, oshii, aneurin, reuven, asuka,
# Nearest to ice: vessels, outgassing, hollow, optimality, purdue, pale, hetero, muonium,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3593 0.4922 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3125 0.4910 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3774 0.4871 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3647 0.4859 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3872 0.4877 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2988 0.4904 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3043 0.4803 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3461 0.4844 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2229 0.4863 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2932 0.4843 sec/batch
# Nearest to history: jordan, harmed, unwavering, uis, tribunes, astute, dresses, bully,
# Nearest to s: revue, matt, tenures, distinctively, lupin, cathari, burden, licensee,
# Nearest to system: data, citigroup, dreadful, security, netscape, corba, stibitz, mib,
# Nearest to his: denunciation, crusade, nephew, accusations, worshipped, famous, rape, praetorians,
# Nearest to a: lunations, modems, validate, bedrooms, abnormality, gibraltarian, connoisseurs, lozenge,
# Nearest to an: definiteness, krishnamurti, floss, straws, versatility, spare, iptables, traumatized,
# Nearest to these: signifier, appropriate, subexpression, noche, theorie, overlapping, patterns, some,
# Nearest to or: legitimate, wintertime, advisable, alternating, coronal, summertime, incapable, bish,
# Nearest to grand: goers, porter, uninfected, holliday, adventist, gemini, paedophilia, taming,
# Nearest to issue: retrieved, fledging, fgth, agenda, dared, constitutionality, blackstone, mcpherson,
# Nearest to notes: bling, testaments, solidifying, ancyra, pappus, iala, colleen, straining,
# Nearest to defense: purview, resign, federal, mandated, euston, regarding, instances, litoral,
# Nearest to construction: angolan, cardoso, pontoon, goods, jutes, taxi, intramuscular, courtyard,
# Nearest to units: consult, numbering, tent, surfacing, construction, deng, damp, gorge,
# Nearest to dr: pleasing, arno, oilers, aneurin, revealing, columnist, reuven, give,
# Nearest to ice: vessels, outgassing, hollow, pale, purdue, optimality, hetero, muonium,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3037 0.4923 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2950 0.4893 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3277 0.2276 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2507 0.5100 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2295 0.4901 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2189 0.4879 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2577 0.4858 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2090 0.4883 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2345 0.4846 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1784 0.4877 sec/batch
# Nearest to history: jordan, harmed, unwavering, uis, historiography, astute, dresses, suffixes,
# Nearest to s: revue, tenures, lupin, matt, pumping, licensee, burden, cathari,
# Nearest to system: data, dreadful, citigroup, mib, windows, display, netscape, stibitz,
# Nearest to his: denunciation, accusations, crusade, worshipped, nephew, praetorians, anarchy, famous,
# Nearest to a: lunations, modems, lozenge, greenlandic, marko, gibraltarian, validate, bedrooms,
# Nearest to an: definiteness, krishnamurti, floss, versatility, straws, spare, kaline, stiffness,
# Nearest to these: signifier, noche, subexpression, overlapping, appropriate, some, patterns, theorie,
# Nearest to or: legitimate, wintertime, bish, advisable, incapable, coronal, summertime, alternating,
# Nearest to grand: goers, porter, uninfected, holliday, breakdance, taming, paedophilia, golovachev,
# Nearest to issue: retrieved, fledging, fgth, dared, mcpherson, rattled, blackstone, esset,
# Nearest to notes: bling, testaments, solidifying, colleen, pappus, ancyra, iala, critique,
# Nearest to defense: purview, resign, mandated, checks, instances, federal, grandparents, euston,
# Nearest to construction: angolan, pontoon, cardoso, courtyard, taxi, blocked, jutes, garten,
# Nearest to units: consult, numbering, zero, tent, surfacing, construction, deng, bitnet,
# Nearest to dr: pleasing, arno, aneurin, columnist, oilers, reuven, revealing, give,
# Nearest to ice: vessels, outgassing, pale, hollow, stones, storms, purdue, pits,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2658 0.4918 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2484 0.4844 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2458 0.4857 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1305 0.4895 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1873 0.4874 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1569 0.4852 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1772 0.4837 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2021 0.4855 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2034 0.4873 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1800 0.4845 sec/batch
# Nearest to history: jordan, uis, harmed, unwavering, historiography, suffixes, factbook, mitanni,
# Nearest to s: revue, tenures, matt, licensee, lupin, snatchers, pumping, burden,
# Nearest to system: dreadful, citigroup, mebyon, stibitz, data, tunneling, mib, atari,
# Nearest to his: denunciation, accusations, worshipped, crusade, praetorians, nephew, he, famous,
# Nearest to a: lunations, abnormality, modems, wasps, eyed, unsuspecting, distances, captioned,
# Nearest to an: definiteness, krishnamurti, floss, ketterle, straws, stiffness, allocate, clamp,
# Nearest to these: subexpression, signifier, some, appropriate, patterns, overlapping, noche, theorie,
# Nearest to or: bish, advisable, incapable, alternating, legitimate, universitas, coronal, wintertime,
# Nearest to grand: holliday, goers, porter, uninfected, breakdance, taming, adventist, gemini,
# Nearest to issue: retrieved, fledging, fgth, cognitively, esset, dared, blackstone, mcpherson,
# Nearest to notes: bling, solidifying, testaments, pappus, ancyra, polyhedra, yeni, critique,
# Nearest to defense: purview, checks, resign, federal, instances, mandated, euston, bill,
# Nearest to construction: angolan, pontoon, jutes, courtyard, blocked, cardoso, taxi, garten,
# Nearest to units: consult, numbering, zero, construction, surfacing, tent, deng, agr,
# Nearest to dr: pleasing, columnist, arno, reuven, aneurin, oilers, oshii, cistercian,
# Nearest to ice: vessels, outgassing, stones, pale, hollow, storms, muonium, nucleophilic,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1852 0.4944 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2025 0.5087 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1497 0.5104 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1555 0.4853 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1779 0.4855 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1936 0.4855 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1978 0.4930 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1407 0.4836 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1186 0.4865 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1955 0.4870 sec/batch
# Nearest to history: jordan, uis, unwavering, reductionism, harmed, factbook, historiography, suffixes,
# Nearest to s: tenures, revue, matt, snatchers, translational, lupin, licensee, cathari,
# Nearest to system: mebyon, citigroup, corba, dreadful, mib, stibitz, unstructured, data,
# Nearest to his: denunciation, he, accusations, famous, worshipped, crusade, predicted, nephew,
# Nearest to a: lunations, modems, targaryen, validate, recovered, eyed, dreamed, extractor,
# Nearest to an: krishnamurti, definiteness, stiffness, floss, straws, blob, ketterle, iptables,
# Nearest to these: signifier, subexpression, appropriate, theorie, flatus, overlapping, some, noche,
# Nearest to or: bish, unforeseen, alternating, charred, legitimate, advisable, summertime, wintertime,
# Nearest to grand: goers, holliday, uninfected, porter, adventist, breakdance, sneak, perelman,
# Nearest to issue: retrieved, fledging, agenda, constitutionality, cognitively, fgth, mcpherson, rattled,
# Nearest to notes: bling, yeni, pappus, critique, colleen, testaments, mapquest, solidifying,
# Nearest to defense: purview, checks, resign, federal, grandparents, mandated, euston, lawful,
# Nearest to construction: angolan, pontoon, courtyard, taxi, jutes, blocked, goods, garten,
# Nearest to units: consult, numbering, surfacing, zero, construction, discharges, deng, shorted,
# Nearest to dr: pleasing, aneurin, give, columnist, reuven, arno, oilers, revealing,
# Nearest to ice: outgassing, vessels, pale, stones, hollow, storms, nucleophilic, muonium,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1826 0.4886 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1621 0.4861 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1844 0.4867 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1651 0.4868 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1274 0.4860 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1678 0.4858 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1823 0.4862 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1443 0.4873 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1858 0.4916 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1867 0.5140 sec/batch
# Nearest to history: jordan, historiography, factbook, unwavering, timeline, uis, harmed, reductionism,
# Nearest to s: tenures, revue, snatchers, matt, licensee, lupin, burden, uncivilized,
# Nearest to system: mebyon, dreadful, citigroup, stibitz, mib, corba, colloquium, adequately,
# Nearest to his: denunciation, he, nephew, fellow, halley, accusations, famous, anarchy,
# Nearest to a: lunations, dreamed, targaryen, recovered, oppressive, eyed, connoisseurs, improvisational,
# Nearest to an: krishnamurti, definiteness, versatility, traumatized, flensburg, herbert, duma, dilmun,
# Nearest to these: subexpression, signifier, theorie, appropriate, noche, flatus, overlapping, imagesize,
# Nearest to or: unforeseen, debtors, advisable, legitimate, bish, wintertime, gong, charred,
# Nearest to grand: goers, holliday, porter, uninfected, adventist, perelman, breakdance, sneak,
# Nearest to issue: retrieved, fledging, constitutionality, agenda, condoned, mcpherson, blackstone, esset,
# Nearest to notes: bling, yeni, pappus, testaments, critique, intension, ancyra, mapquest,
# Nearest to defense: purview, checks, mandated, lawful, federal, camps, resign, instances,
# Nearest to construction: angolan, pontoon, courtyard, jutes, garten, blocked, cardoso, taxi,
# Nearest to units: consult, numbering, surfacing, caesar, construction, deng, casares, tent,
# Nearest to dr: pleasing, aneurin, reuven, give, arno, columnist, oshii, eleftherios,
# Nearest to ice: outgassing, stones, vessels, pale, nucleophilic, hollow, muonium, swimming,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2418 0.5115 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1302 0.4867 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1182 0.4816 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1612 0.5455 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0151 0.5783 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1216 0.5645 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1433 0.6043 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1283 0.5902 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1627 0.1009 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1455 0.6291 sec/batch
# Nearest to history: jordan, uis, unwavering, factbook, historiography, reductionism, timeline, harmed,
# Nearest to s: revue, tenures, snatchers, matt, licensee, uncivilized, burden, lupin,
# Nearest to system: dreadful, mebyon, citigroup, mib, stibitz, colloquium, corba, adequately,
# Nearest to his: denunciation, he, predicted, accusations, nephew, halley, unleash, anarchy,
# Nearest to a: lunations, modems, extractor, volleys, improvisational, targaryen, distances, gibraltarian,
# Nearest to an: krishnamurti, definiteness, traumatized, ketterle, versatility, blob, straws, floss,
# Nearest to these: subexpression, signifier, flatus, theorie, patterns, some, appropriate, noche,
# Nearest to or: advisable, unforeseen, debtors, legitimate, bish, alternating, diacritics, pupa,
# Nearest to grand: goers, holliday, porter, adventist, uninfected, canopies, uprisings, perelman,
# Nearest to issue: retrieved, fledging, mcpherson, esset, blackstone, condoned, bangui, fgth,
# Nearest to notes: bling, yeni, pappus, testaments, critique, intension, polyhedra, cryonics,
# Nearest to defense: purview, checks, resign, mandated, bill, camps, euston, federal,
# Nearest to construction: angolan, pontoon, courtyard, goods, garten, damp, capacitors, jutes,
# Nearest to units: consult, numbering, surfacing, caesar, tent, deng, casares, zero,
# Nearest to dr: aneurin, pleasing, reuven, give, columnist, eleftherios, arno, cleve,
# Nearest to ice: outgassing, stones, pale, vessels, nucleophilic, hollow, swimming, storms,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0786 0.6289 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0700 0.5896 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0823 0.5768 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0570 0.5971 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0595 0.5779 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0511 0.6148 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0878 0.5414 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0753 0.4890 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1216 0.4883 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0569 0.5255 sec/batch
# Nearest to history: jordan, uis, factbook, historiography, unwavering, harmed, reductionism, leone,
# Nearest to s: revue, tenures, licensee, snatchers, lupin, pumping, matt, burden,
# Nearest to system: citigroup, tunneling, mebyon, mib, stibitz, corba, atari, dreadful,
# Nearest to his: denunciation, he, accusations, nephew, busts, fellow, famous, predicted,
# Nearest to a: lunations, modems, distances, deacons, extractor, validate, improvisational, lozenge,
# Nearest to an: krishnamurti, definiteness, stiffness, blob, ketterle, ll, pastor, labeling,
# Nearest to these: some, subexpression, patterns, flatus, appropriate, overs, masorti, sonar,
# Nearest to or: alternating, unforeseen, advisable, bish, debtors, pupa, are, diacritics,
# Nearest to grand: goers, holliday, adventist, canopies, porter, perelman, uprisings, uninfected,
# Nearest to issue: retrieved, fledging, esset, mcpherson, rattled, bangui, condoned, blackstone,
# Nearest to notes: bling, testaments, yeni, critique, pappus, intension, cryonics, unaccompanied,
# Nearest to defense: purview, checks, mandated, resign, lawful, camps, euston, grandparents,
# Nearest to construction: angolan, pontoon, courtyard, garten, goods, capacitors, groupe, attracting,
# Nearest to units: numbering, consult, surfacing, zero, caesar, tapering, shorted, casares,
# Nearest to dr: aneurin, pleasing, columnist, reuven, give, cleve, ulbricht, eleftherios,
# Nearest to ice: outgassing, pale, stones, swimming, nucleophilic, hollow, glacier, vessels,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0073 0.5699 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0173 0.5491 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0177 0.5785 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0425 0.5850 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0743 0.6297 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0564 0.6132 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0580 0.6137 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1138 0.6003 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0855 0.6446 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0582 0.5983 sec/batch
# Nearest to history: uis, jordan, unwavering, historiography, factbook, timeline, harmed, chmielnicki,
# Nearest to s: revue, tenures, snatchers, matt, licensee, lupin, translational, basis,
# Nearest to system: mebyon, corba, tunneling, citigroup, stibitz, mib, dreadful, unstructured,
# Nearest to his: he, denunciation, nephew, famous, died, predicted, fellow, accusations,
# Nearest to a: lunations, modems, deacons, extractor, distances, abnormality, validate, scalability,
# Nearest to an: krishnamurti, definiteness, stiffness, multilinear, ketterle, blob, labeling, field,
# Nearest to these: subexpression, signifier, flatus, patterns, imagesize, some, appropriate, theorie,
# Nearest to or: alternating, unforeseen, are, legitimate, bish, incapable, debtors, summertime,
# Nearest to grand: goers, holliday, adventist, porter, canopies, uprisings, perelman, uninfected,
# Nearest to issue: retrieved, fledging, esset, coherent, blackstone, superheroes, condoned, cognitively,
# Nearest to notes: bling, yeni, testaments, intension, critique, pappus, polyhedra, cryonics,
# Nearest to defense: purview, checks, resign, mandated, lawful, camps, perception, euston,
# Nearest to construction: angolan, courtyard, pontoon, goods, garten, capacitors, groupe, invention,
# Nearest to units: consult, numbering, surfacing, caesar, dipole, mnp, resonant, casares,
# Nearest to dr: aneurin, columnist, pleasing, reuven, cleve, give, jacobs, esoc,
# Nearest to ice: outgassing, nucleophilic, stones, pale, hollow, swimming, hetero, glacier,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0631 0.6651 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0917 0.6716 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0600 0.6344 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0694 0.6035 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0759 0.5970 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0172 0.5850 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0628 0.5901 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0568 0.5828 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0632 0.5861 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0873 0.5970 sec/batch
# Nearest to history: historiography, factbook, timeline, jordan, unwavering, uis, overviews, leone,
# Nearest to s: tenures, revue, snatchers, argumentation, uncivilized, matt, anna, smoker,
# Nearest to system: mebyon, corba, stibitz, tunneling, citigroup, mib, dreadful, atari,
# Nearest to his: he, denunciation, nephew, famous, died, fellow, praetorians, predicted,
# Nearest to a: lunations, deacons, eyed, recovered, validate, extractor, infringes, consolations,
# Nearest to an: krishnamurti, definiteness, ketterle, multilinear, argumentative, libertarians, stiffness, leaderships,
# Nearest to these: imagesize, subexpression, signifier, masorti, patterns, flatus, sonar, appropriate,
# Nearest to or: unforeseen, debtors, bish, are, grudgingly, continual, advisable, charred,
# Nearest to grand: goers, adventist, uprisings, holliday, publicized, trinity, porter, canopies,
# Nearest to issue: retrieved, condoned, fledging, superheroes, mcpherson, coherent, blackstone, esset,
# Nearest to notes: bling, yeni, intension, testaments, pappus, critique, polyhedra, mapquest,
# Nearest to defense: purview, checks, mandated, grandparents, euston, instances, camps, lawful,
# Nearest to construction: angolan, courtyard, pontoon, goods, tima, garten, capacitors, groupe,
# Nearest to units: consult, numbering, casares, surfacing, caesar, zero, gmc, dipole,
# Nearest to dr: aneurin, pleasing, columnist, reuven, give, cleve, roz, esoc,
# Nearest to ice: outgassing, nucleophilic, pale, stones, swimming, hollow, hetero, storms,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0172 0.6249 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9998 0.6100 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0178 0.6200 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0625 0.6204 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0888 0.6225 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1119 0.6680 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1283 0.6430 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0245 0.5613 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0451 0.5126 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0550 0.5088 sec/batch
# Nearest to history: jordan, historiography, timeline, uis, factbook, unwavering, overviews, leone,
# Nearest to s: revue, tenures, argumentation, snatchers, anna, uncivilized, translational, matt,
# Nearest to system: mebyon, tunneling, stibitz, citigroup, dreadful, mib, passes, colloquium,
# Nearest to his: he, denunciation, nephew, fellow, died, famous, halley, sergius,
# Nearest to a: lunations, extractor, group, infringes, validate, bitstrings, improvisational, deacons,
# Nearest to an: krishnamurti, definiteness, the, payload, argumentative, ketterle, pastor, traumatized,
# Nearest to these: imagesize, subexpression, patterns, masorti, appropriate, flatus, some, both,
# Nearest to or: are, unforeseen, alternating, advisable, charred, implants, continual, debtors,
# Nearest to grand: goers, adventist, holliday, uprisings, publicized, trinity, porter, canopies,
# Nearest to issue: retrieved, fledging, superheroes, mcpherson, esset, blackstone, condoned, coherent,
# Nearest to notes: bling, intension, testaments, pappus, yeni, critique, unaccompanied, cryonics,
# Nearest to defense: purview, checks, camps, mandated, lawful, euston, enquiries, resign,
# Nearest to construction: angolan, courtyard, pontoon, goods, garten, capacitors, tima, overhang,
# Nearest to units: consult, numbering, casares, caesar, surfacing, gmc, tent, si,
# Nearest to dr: aneurin, pleasing, columnist, reuven, cleve, give, ulbricht, roz,
# Nearest to ice: outgassing, nucleophilic, swimming, pale, storms, stones, hollow, purdue,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9879 0.5443 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0145 0.5899 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0549 0.6381 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0333 0.5115 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0752 0.6535 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0845 0.5392 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0190 0.6093 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9684 0.5988 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0520 0.5653 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9735 0.5413 sec/batch
# Nearest to history: historiography, unwavering, uis, timeline, jordan, factbook, more, chmielnicki,
# Nearest to s: revue, tenures, snatchers, matt, argumentation, anna, translational, licensee,
# Nearest to system: tunneling, mebyon, unstructured, lynx, citigroup, mib, stibitz, atari,
# Nearest to his: he, nephew, denunciation, died, busts, nara, fellow, praetorians,
# Nearest to a: lunations, deacons, infringes, modems, validate, group, abnormality, inhospitable,
# Nearest to an: krishnamurti, the, payload, definiteness, hectare, stiffness, ketterle, argumentative,
# Nearest to these: imagesize, patterns, masorti, subexpression, some, flatus, both, sonar,
# Nearest to or: unforeseen, charred, are, americans, alternating, advisable, continual, implants,
# Nearest to grand: goers, holliday, adventist, canopies, uprisings, trinity, limerick, publicized,
# Nearest to issue: retrieved, superheroes, fledging, coherent, mcpherson, esset, bangui, condoned,
# Nearest to notes: bling, intension, yeni, testaments, pappus, unaccompanied, critique, cryonics,
# Nearest to defense: purview, checks, mandated, camps, lawful, instances, euston, grandparents,
# Nearest to construction: angolan, courtyard, pontoon, goods, garten, tima, attracting, groupe,
# Nearest to units: consult, numbering, casares, surfacing, si, gmc, tent, caesar,
# Nearest to dr: aneurin, ulbricht, cleve, reuven, pleasing, columnist, give, dds,
# Nearest to ice: outgassing, nucleophilic, swimming, pale, glacier, purdue, hetero, storms,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0230 0.5662 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9627 0.5636 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0522 0.5601 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0226 0.4957 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0318 0.4858 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0142 0.4908 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9217 0.4886 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9652 0.4851 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9471 0.5110 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9641 0.5039 sec/batch
# Nearest to history: uis, factbook, historiography, jordan, more, timeline, unwavering, overviews,
# Nearest to s: revue, tenures, snatchers, matt, translational, anna, burden, whittier,
# Nearest to system: mebyon, tunneling, stibitz, communicable, mib, citigroup, colloquium, passes,
# Nearest to his: he, denunciation, nephew, died, fellow, busts, famous, him,
# Nearest to a: lunations, is, deacons, group, scalability, abnormality, extractor, into,
# Nearest to an: krishnamurti, the, payload, definiteness, gnomon, pastor, possessing, dilmun,
# Nearest to these: imagesize, subexpression, patterns, some, masorti, often, both, flatus,
# Nearest to or: are, alternating, button, charred, advisable, americans, unforeseen, is,
# Nearest to grand: canopies, goers, holliday, adventist, uprisings, limerick, publicized, perelman,
# Nearest to issue: retrieved, superheroes, fledging, mcpherson, coherent, condoned, esset, blackstone,
# Nearest to notes: bling, intension, critique, yeni, testaments, unaccompanied, calories, pappus,
# Nearest to defense: purview, checks, camps, instances, heavily, euston, norton, lawful,
# Nearest to construction: courtyard, angolan, pontoon, garten, tima, attracting, goods, groupe,
# Nearest to units: numbering, consult, casares, surfacing, zero, si, caesar, tent,
# Nearest to dr: aneurin, cleve, reuven, columnist, ulbricht, pleasing, jacobs, revamping,
# Nearest to ice: outgassing, nucleophilic, swimming, pale, storms, stones, glacier, hetero,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0158 0.5075 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9964 0.4893 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9706 0.4862 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0300 0.4855 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0031 0.4893 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9485 0.4872 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9965 0.4839 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0100 0.4870 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9943 0.5156 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9693 0.5028 sec/batch
# Nearest to history: uis, historiography, factbook, jordan, more, unwavering, timeline, overviews,
# Nearest to s: snatchers, revue, anna, tenures, matt, argumentation, licensee, tard,
# Nearest to system: mebyon, tunneling, passes, stibitz, dreadful, colloquium, atari, mib,
# Nearest to his: he, died, nephew, denunciation, famous, busts, fellow, him,
# Nearest to a: lunations, is, deacons, group, extractor, by, of, hemphill,
# Nearest to an: krishnamurti, the, payload, argumentative, possessing, lithograph, definiteness, of,
# Nearest to these: imagesize, subexpression, patterns, masorti, both, communities, appropriate, often,
# Nearest to or: are, charred, unforeseen, alternating, button, islander, americans, summertime,
# Nearest to grand: canopies, goers, adventist, holliday, trinity, publicized, uprisings, axles,
# Nearest to issue: retrieved, superheroes, coherent, leaders, fledging, condoned, blackstone, mcpherson,
# Nearest to notes: bling, intension, critique, testaments, yeni, unaccompanied, pappus, bahamas,
# Nearest to defense: purview, checks, camps, norton, instances, euston, heavily, sherrill,
# Nearest to construction: courtyard, angolan, pontoon, attracting, goods, garten, invention, capacitors,
# Nearest to units: consult, numbering, casares, surfacing, caesar, tent, dipole, si,
# Nearest to dr: aneurin, reuven, pleasing, cleve, ulbricht, dre, columnist, give,
# Nearest to ice: outgassing, nucleophilic, swimming, pale, hollow, hetero, stones, storms,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9956 0.5214 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9757 0.5038 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9841 0.4899 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0218 0.4895 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9951 0.4883 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0308 0.4874 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0068 0.4861 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9772 0.4858 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9721 0.4826 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0191 0.4868 sec/batch
# Nearest to history: historiography, factbook, jordan, uis, overviews, timeline, unwavering, more,
# Nearest to s: snatchers, tenures, anna, revue, argumentation, matt, presidio, baronet,
# Nearest to system: mebyon, tunneling, passes, stibitz, communicable, dreadful, mib, colloquium,
# Nearest to his: he, died, nephew, denunciation, andreotti, fellow, famous, probably,
# Nearest to a: lunations, deacons, group, of, is, also, in, by,
# Nearest to an: krishnamurti, the, payload, argumentative, relations, of, definiteness, hectare,
# Nearest to these: imagesize, both, masorti, subexpression, patterns, communities, flatus, some,
# Nearest to or: are, unforeseen, grudgingly, charred, is, americans, continual, alternating,
# Nearest to grand: canopies, goers, trinity, adventist, publicized, holliday, uprisings, axles,
# Nearest to issue: retrieved, superheroes, fledging, blackstone, mcpherson, coherent, leaders, condoned,
# Nearest to notes: bling, intension, critique, yeni, unaccompanied, tunes, testaments, bahamas,
# ...
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8512 0.5671 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8809 0.5482 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8543 0.5814 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8582 0.5122 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9216 0.5604 sec/batch
# Nearest to history: pdf, external, overviews, historiography, century, factbook, heraldry, timeline,
# Nearest to s: the, is, of, in, snatchers, a, anna, with,
# Nearest to system: its, the, mebyon, tunneling, operating, passes, communicable, landline,
# Nearest to his: he, him, nephew, friends, died, spent, nara, work,
# Nearest to a: the, of, in, as, is, and, with, also,
# Nearest to an: the, of, a, being, and, which, softworks, is,
# Nearest to these: both, imagesize, instructions, patterns, often, among, eluded, polymeric,
# Nearest to or: are, also, is, of, islander, a, other, non,
# Nearest to grand: trinity, canopies, adventist, trance, wettin, promenade, axles, wehrmacht,
# Nearest to issue: superheroes, retrieved, leaders, fledging, book, able, exist, timely,
# Nearest to notes: testaments, publications, unaccompanied, bells, rfloor, bahamas, calories, colossians,
# Nearest to defense: purview, rea, lethality, norton, ncs, ppr, chang, battlegroup,
# Nearest to construction: tima, hutchinson, courtyard, attracting, groupe, garten, pontoon, appliances,
# Nearest to units: unit, numbering, si, casares, caesar, battalion, civilians, consult,
# Nearest to dr: dre, chronic, cleve, aneurin, dds, reuven, irritable, revamping,
# Nearest to ice: glacier, nucleophilic, glaciers, blades, hwv, swimming, anguilla, glacial,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8340 0.5500 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8404 0.5563 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8482 0.5533 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8764 0.5676 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8624 0.5702 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8795 0.5414 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8696 0.5424 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8320 0.5882 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8892 0.6230 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8750 0.5697 sec/batch
# Nearest to history: historiography, pdf, century, overviews, external, factbook, blackwell, heraldry,
# Nearest to s: the, of, with, is, in, and, its, snatchers,
# Nearest to system: its, mebyon, passes, operating, tunneling, systems, landline, communicable,
# Nearest to his: he, him, nephew, died, spent, tutor, nara, friends,
# Nearest to a: the, in, as, of, is, with, by, an,
# Nearest to an: the, of, a, being, in, and, which, with,
# Nearest to these: both, among, often, imagesize, polymeric, patterns, mid, instructions,
# Nearest to or: are, is, also, certain, of, islander, non, other,
# Nearest to grand: trinity, canopies, wettin, adventist, axles, trance, promenade, borg,
# Nearest to issue: superheroes, retrieved, leaders, able, book, fledging, inc, timely,
# Nearest to notes: publications, testaments, unaccompanied, rfloor, bells, emporia, bahamas, colossians,
# Nearest to defense: purview, rea, lethality, norton, chang, ncs, camps, ppr,
# Nearest to construction: tima, pontoon, attracting, appliances, courtyard, garten, hutchinson, acl,
# Nearest to units: numbering, unit, si, casares, caesar, mandaean, battalion, civilians,
# Nearest to dr: dre, chronic, cleve, aneurin, dds, irritable, reuven, revamping,
# Nearest to ice: glacier, glaciers, glacial, nucleophilic, blades, anguilla, hwv, outgassing,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8514 0.6005 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8498 0.5999 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8432 0.6219 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8640 0.5806 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8807 0.6125 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8544 0.5865 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9532 0.6175 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9175 0.5869 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9544 0.5498 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8186 0.5103 sec/batch
# Nearest to history: historiography, pdf, external, overviews, timeline, century, factbook, blackwell,
# Nearest to s: the, in, with, is, of, a, anna, its,
# Nearest to system: its, mebyon, the, passes, systems, operating, forcefully, colloquium,
# Nearest to his: he, him, nephew, spent, work, tutor, devote, died,
# Nearest to a: as, the, in, of, by, is, with, has,
# Nearest to an: the, of, a, which, in, being, with, main,
# Nearest to these: both, among, imagesize, patterns, are, mostly, polymeric, hundreds,
# Nearest to or: are, is, non, also, of, other, two, certain,
# Nearest to grand: trinity, wettin, canopies, adventist, wehrmacht, promenade, perpignan, politicians,
# Nearest to issue: retrieved, superheroes, leaders, book, fledging, exist, hardcover, inc,
# Nearest to notes: testaments, publications, unaccompanied, bells, rfloor, colossians, bahamas, emporia,
# Nearest to defense: purview, rea, lethality, camps, norton, battlegroup, facilitation, ncs,
# Nearest to construction: tima, pontoon, hutchinson, attracting, garten, appliances, acl, groupe,
# Nearest to units: numbering, unit, si, casares, civilians, mandaean, confronted, alden,
# Nearest to dr: dre, interment, cleve, chronic, reuven, aneurin, revamping, disclaimed,
# Nearest to ice: glacier, glaciers, nucleophilic, blades, swimming, anguilla, glacial, hwv,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8022 0.4914 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8811 0.5115 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7752 0.4905 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8570 0.4982 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8387 0.4877 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8434 0.4910 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9415 0.2356 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8464 0.4859 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8310 0.4919 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8235 0.5438 sec/batch
# Nearest to history: historiography, pdf, timeline, century, external, overviews, blackwell, heraldry,
# Nearest to s: the, is, of, a, with, anna, its, in,
# Nearest to system: its, mebyon, systems, operating, passes, develop, communicable, tunneling,
# Nearest to his: he, him, nephew, tutor, died, spent, zainab, son,
# Nearest to a: the, in, as, of, by, is, with, an,
# Nearest to an: the, of, a, which, being, is, and, to,
# Nearest to these: both, among, often, polymeric, hundreds, imagesize, some, are,
# Nearest to or: is, are, non, also, of, there, unforeseen, certain,
# Nearest to grand: trinity, canopies, wettin, adventist, trance, perpignan, promenade, axles,
# Nearest to issue: retrieved, superheroes, fledging, leaders, book, timely, fancher, esset,
# Nearest to notes: publications, testaments, unaccompanied, bells, diatonic, rfloor, bahamas, colossians,
# Nearest to defense: purview, rea, norton, lethality, battlegroup, ncs, camps, meritorious,
# Nearest to construction: tima, pontoon, attracting, garten, acl, hutchinson, grammatical, groupe,
# Nearest to units: si, unit, numbering, casares, battalion, demonym, confronted, civilians,
# Nearest to dr: dre, interment, chronic, aneurin, cleve, reuven, irritable, revamping,
# Nearest to ice: glacier, glaciers, anguilla, nucleophilic, swimming, blades, frozen, hwv,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8377 0.5306 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7998 0.5238 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8476 0.5221 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8053 0.5246 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8648 0.5442 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8518 0.5530 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8846 0.5187 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7718 0.4883 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7943 0.4861 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8060 0.4912 sec/batch
# Nearest to history: pdf, historiography, century, timeline, blackwell, overviews, external, heraldry,
# Nearest to s: the, is, a, of, its, with, in, anna,
# Nearest to system: its, mebyon, the, systems, operating, passes, develop, communicable,
# Nearest to his: he, him, nephew, tutor, zainab, spent, work, devote,
# Nearest to a: in, the, as, is, of, for, also, an,
# Nearest to an: the, of, a, which, is, to, being, in,
# Nearest to these: both, among, often, polymeric, imagesize, are, some, pacifists,
# Nearest to or: are, is, also, of, there, non, a, other,
# Nearest to grand: trinity, canopies, wettin, adventist, trance, axles, borg, perpignan,
# Nearest to issue: superheroes, retrieved, leaders, fledging, book, inc, timely, esset,
# Nearest to notes: testaments, publications, unaccompanied, rfloor, bells, bahamas, diatonic, colossians,
# Nearest to defense: rea, purview, battlegroup, lethality, camps, arbiter, norton, meritorious,
# Nearest to construction: tima, attracting, garten, pontoon, build, capacitors, appliances, acl,
# Nearest to units: unit, si, numbering, confronted, casares, caesar, mandaean, battalion,
# Nearest to dr: dre, cleve, interment, reuven, aneurin, chronic, dds, pundit,
# Nearest to ice: glacier, glaciers, frozen, anguilla, blades, swimming, nucleophilic, glacial,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7578 0.4891 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8130 0.4888 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8592 0.5093 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8157 0.5157 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8234 0.4847 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8760 0.4881 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8501 0.4851 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8043 0.4884 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8362 0.4861 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8454 0.4849 sec/batch
# Nearest to history: pdf, timeline, historiography, blackwell, external, overviews, summary, century,
# Nearest to s: the, is, of, in, its, a, with, and,
# Nearest to system: its, systems, mebyon, the, passes, operating, forcefully, colloquium,
# Nearest to his: he, him, nephew, spent, work, died, tutor, friends,
# Nearest to a: the, in, of, as, is, also, by, an,
# Nearest to an: the, of, a, which, in, is, to, and,
# Nearest to these: both, among, often, are, polymeric, patterns, imagesize, mostly,
# Nearest to or: are, is, also, there, of, other, non, have,
# Nearest to grand: trinity, canopies, wettin, adventist, borg, trance, perpignan, politicians,
# Nearest to issue: superheroes, retrieved, leaders, book, fledging, timely, esset, inc,
# Nearest to notes: publications, unaccompanied, testaments, rfloor, bells, fell, bahamas, diatonic,
# Nearest to defense: rea, purview, norton, battlegroup, lethality, meritorious, arbiter, camps,
# Nearest to construction: tima, acl, appliances, pontoon, attracting, grammatical, capacitors, garten,
# Nearest to units: unit, si, numbering, confronted, mandaean, casares, caesar, battalion,
# Nearest to dr: dre, chronic, dds, cleve, aneurin, interment, reuven, revamping,
# Nearest to ice: glacier, glaciers, frozen, anguilla, blades, nucleophilic, hwv, glacial,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8771 0.4920 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8242 0.4854 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8105 0.4876 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8432 0.4869 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8574 0.4909 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8400 0.4950 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8239 0.4855 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8744 0.4857 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8088 0.4876 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8035 0.4852 sec/batch
# Nearest to history: timeline, historiography, external, pdf, blackwell, overviews, summary, references,
# Nearest to s: the, is, of, in, and, its, with, also,
# Nearest to system: its, the, systems, mebyon, forcefully, operating, passes, develop,
# Nearest to his: he, him, nephew, spent, tutor, nara, zainab, died,
# Nearest to a: as, the, in, is, of, also, by, for,
# Nearest to an: the, of, a, which, in, and, is, also,
# Nearest to these: both, among, are, often, some, mostly, patterns, most,
# Nearest to or: are, also, is, a, there, of, non, other,
# Nearest to grand: trinity, canopies, wettin, adventist, politicians, perpignan, axles, promenade,
# Nearest to issue: superheroes, retrieved, leaders, timely, fledging, able, inc, book,
# Nearest to notes: publications, rfloor, unaccompanied, note, testaments, bells, fell, diatonic,
# Nearest to defense: purview, rea, norton, lethality, meritorious, battlegroup, camps, ncs,
# Nearest to construction: tima, pontoon, acl, garten, hutchinson, capacitors, attracting, grammatical,
# Nearest to units: unit, si, mandaean, confronted, numbering, caesar, casares, battalion,
# Nearest to dr: dre, chronic, cleve, dds, interment, aneurin, pundit, reuven,
# Nearest to ice: glacier, blades, glaciers, frozen, swimming, anguilla, nucleophilic, hwv,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8548 0.5008 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8238 0.5114 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8938 0.4907 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9212 0.5035 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9088 0.4962 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8362 0.5274 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7841 0.5056 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8199 0.5869 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7417 0.4994 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8656 0.4893 sec/batch
# Nearest to history: timeline, external, historiography, blackwell, pdf, see, overviews, summary,
# Nearest to s: the, is, in, with, of, anna, and, its,
# Nearest to system: its, systems, the, passes, operating, mebyon, develop, forcefully,
# Nearest to his: he, him, spent, work, nephew, devote, folger, died,
# Nearest to a: as, is, the, in, of, also, by, with,
# Nearest to an: the, of, a, which, is, in, being, and,
# Nearest to these: both, among, are, often, patterns, some, hundreds, mostly,
# Nearest to or: is, are, also, of, a, non, there, other,
# Nearest to grand: wettin, trinity, canopies, politicians, adventist, promenade, borg, perpignan,
# Nearest to issue: superheroes, retrieved, leaders, inc, timely, esset, book, hardcover,
# Nearest to notes: publications, testaments, unaccompanied, rfloor, diatonic, fell, colossians, note,
# Nearest to defense: purview, rea, norton, lethality, camps, meritorious, ncs, battlegroup,
# Nearest to construction: tima, pontoon, hutchinson, garten, grammatical, acl, capacitors, appliances,
# Nearest to units: unit, si, mandaean, confronted, numbering, casares, metric, thurber,
# Nearest to dr: dre, interment, cleve, chronic, aneurin, dds, disclaimed, reuven,
# Nearest to ice: glacier, glaciers, blades, frozen, swimming, anguilla, nucleophilic, glacial,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8436 0.4926 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8319 0.4956 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
